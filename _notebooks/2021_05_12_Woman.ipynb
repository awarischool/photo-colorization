# %% [markdown]
# <a href="https://colab.research.google.com/github/ErycM/photo-colorization/blob/master/_notebooks/2021_05_12_Woman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A Woman
#
# > "A Woman"
#
# - categories: [fastpages, jupyter]
# - name: Eryc Masselli
#
#
# - image: https://i.redd.it/yz5bnr961px61.jpg

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py

# %%
#hide
from deoldify_wrapper import DeOldify

# %%
#hide
deo = DeOldify()

# %%
#hide_input
deo.colorize("https://i.redd.it/yz5bnr961px61.jpg")
