# %% [markdown]
# <a href="https://colab.research.google.com/github/julianaraujo2/photo-colorization/blob/master/_notebooks/2020-12-15_currie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-12-15 17:53:44--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py.1’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-12-15 17:53:45 (46.7 MB/s) - ‘deoldify_wrapper.py.1’ saved [2623/2623]

# %%
#hide
from deoldify_wrapper import DeOldify

# %%
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...
# Done!

# %%
#hide_imput

# %%
deo.colorizer("https://www.amambainoticias.com.br/media/images/612/107108//58b095f985f7c332a8888909a00c72cc635a63183d743.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-ec6686486024> in <module>()
# ----> 1 deo.colorizer("https://www.amambainoticias.com.br/media/images/612/107108//58b095f985f7c332a8888909a00c72cc635a63183d743.jpg")
#
# TypeError: 'ModelImageVisualizer' object is not callable

# %%
#hide_input

# %%
deo.colorize("https://www.amambainoticias.com.br/media/images/612/107108//58b095f985f7c332a8888909a00c72cc635a63183d743.jpg")

# %% [markdown]
# #Colorização Currie
# >Colorização cientista usando rede  DeOldify
# -toc: false
# -branch: master
# -badges: true
# -comments: true
# -categories: [ciência]
