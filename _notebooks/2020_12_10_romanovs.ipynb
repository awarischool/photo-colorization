# %% [markdown]
# <a href="https://colab.research.google.com/github/cpoles/photo-colorization/blob/master/_notebooks/2020_12_10_romanovs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # "The Romanovs"
# > "Photo colorization with Deep Learning applying the DeOldify neural network."
#
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - categories: [data science, neural networks, AI]

# %% [markdown]
# ##### Photo Source: [The Romanov Family](https://ih1.redbubble.net/image.723353202.0361/pp,504x498-pad,600x600,f8f8f8.jpg)

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py #download the deoldify library from GitHub
# Out:
# --2020-12-14 20:37:47--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-12-14 20:37:47 (50.8 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %%
#hide
#import the DeOldify class from the deoldify_wrapper library
from deoldify_wrapper import DeOldify

# %%
#initialise an instance of DeOldify
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Done!

# %%
#hide_input
#colorize photo
deo.colorize('https://ih1.redbubble.net/image.723353202.0361/pp,504x498-pad,600x600,f8f8f8.jpg')
