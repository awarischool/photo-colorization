# %% [markdown]
# # "Foto de uma mãe quando criança em Lefkada, Grécia, de 1963,"
#
# > "Foto colorizada por redes neurais de uma mãe quando criança em Lefkada."
#
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - Author: Wemerson Ferreira
# - categories: [mae, familia, mulher]

# %% [markdown]
# **Declarando Variavel "imagem"**

# %%
#hide
imagem = 'https://i.imgur.com/aj5qqAQ.jpg'

# %% [markdown]
# **Lendo o Valor da Variavel**

# %%
#hide
imagem
# Out:
# 'https://i.imgur.com/aj5qqAQ.jpg'

# %% [markdown]
# **Baixando o deoldify_wrapper.py usando wget**

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2021-03-12 22:51:11--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2021-03-12 22:51:11 (28.5 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %% [markdown]
# **Abrindo o repositorio deoldify_wrapper e importando a biblioteca De0dify**

# %%
#hide
from deoldify_wrapper import DeOldify

# %% [markdown]
# **Declando a Variavel "deo"**

# %%
#hide
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Done!

# %%
#hide_input
deo.colorize(imagem)
