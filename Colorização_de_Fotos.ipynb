# %% [markdown]
# <a href="https://colab.research.google.com/github/naokityokoyama/photo-colorization/blob/master/Coloriza%C3%A7%C3%A3o_de_Fotos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fotos para colorir
#
# > Insira depois de carregar todos os códigos um link de imagem que queira colocar ele deve ter extensão validade de arquivo de foto ex: jpg
# Biblioteca utilizada DeOldfy
# Foi colorizada usando redes neurais e pacote DeOldfy
#
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - author: Naoki Yokoyama
# - categories: [colorir fotos]

# %%
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py #COLCOANDO CODIGO DO LINK PARA DENTRO DO COLAB
# Out:
# --2020-08-04 02:58:25--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2614 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py.2’
#
# deoldify_wrapper.py 100%[===================>]   2.55K  --.-KB/s    in 0s
#
# 2020-08-04 02:58:25 (29.4 MB/s) - ‘deoldify_wrapper.py.2’ saved [2614/2614]

# %%
from deoldify_wrapper import DeOldify # importando a class DeOldify

# %%
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Done!

# %%
link = str(input("insira o link do site "))
deo.colorize(link)
# Out:
# link o site https://historiadores-do-futuro1.webnode.com/_files/200000001-46efe47ecd/286777_Papel-de-Parede-Soldados-na-Segunda-Guerra-Mundial_1366x768.jpg
