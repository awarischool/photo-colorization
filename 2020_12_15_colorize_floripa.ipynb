# %% [markdown]
# <a href="https://colab.research.google.com/github/jrnetot/photo-colorization/blob/master/2020_12_15_colorize_floripa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Florianópolis no século 20
# Colorização do centro de Florianópolis no século 20 usando a rede neural DeOldify
# - toc = fase
# - branch = master
# - badges = true
# - comments = true
# - categories: [colab, fastpages, colorizacao, florianopolis]

# %%
#hide 
# !wget https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-12-15 17:23:15--  https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-12-15 17:23:15 (46.4 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %%
#hide
from deoldify_wrapper import DeOldify
# Out:
#   Importing Libraries
# No module named 'deoldify'
# DeOldify not found, installing..
#   Cloning DeOldify Repository...
#   Opening DeOldify Folder
#   Importing Libraries
# /content/deoldify_wrapper.py:36: UserWarning: WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings
#   warnings.warn('WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings')
#   Installing Colab requirements...
#   Importing DeOldify Visualize module and FastAI
# ...

# %%
#hide
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Done!

# %%
#hide
# !wget https://www.deolhonailha.com.br/fmanager/doni/news/imagem39458_1.jpg
# Out:
# --2020-12-15 17:32:13--  https://www.deolhonailha.com.br/fmanager/doni/news/imagem39458_1.jpg
# Resolving www.deolhonailha.com.br (www.deolhonailha.com.br)... 69.46.2.74
# Connecting to www.deolhonailha.com.br (www.deolhonailha.com.br)|69.46.2.74|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330143 (322K) [image/jpeg]
# Saving to: ‘imagem39458_1.jpg’
#
# imagem39458_1.jpg   100%[===================>] 322.41K  2.04MB/s    in 0.2s
#
# 2020-12-15 17:32:14 (2.04 MB/s) - ‘imagem39458_1.jpg’ saved [330143/330143]

# %%
#hide_input

# %%
deo.colorize("https://www.deolhonailha.com.br/fmanager/doni/news/imagem39458_1.jpg")
